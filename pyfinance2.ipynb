# %%
import import_ipynb
from path import *

# %% [markdown]
# # PATH

# %%
files = [x for x in listdir(PATH) if isfile(join(PATH, x))]
tickers = [os.path.splitext(x)[0] for x in files]
tickers
# Out:
# ['A',
#  'AA',
#  'AAL',
#  'AAME',
#  'AAN',
#  'AAOI',
#  'AAON',
#  'AAP',
#  'AAPL',
#  'AAT',
#  'AAWW',
#  'ABBV',
#  'ABC',
#  'ABCB',
#  'ABEO',
#  'ABG',
#  'ABIO',
#  'ABM',
#  'ABMD',
#  'ABR',
#  'ABT',
#  'ABTX',
#  'AC',
#  'ACA',
#  'ACAD',
#  'ACBI',
#  'ACC',
#  'ACCO',
#  'ACER',
#  'ACGL',
#  'ACHC',
#  'ACHV',
#  'ACIW',
#  'ACLS',
#  'ACM',
#  'ACMR',
#  'ACN',
#  'ACNB',
#  'ACOR',
#  'ACRE',
#  'ACRS',
#  'ACRX',
#  'ACTG',
#  'ACU',
#  'ACY',
#  'ADBE',
#  'ADC',
#  'ADES',
#  'ADI',
#  'ADM',
#  'ADMA',
#  'ADMP',
#  'ADNT',
#  'ADP',
#  'ADS',
#  'ADSK',
#  'ADT',
#  'ADTN',
#  'ADUS',
#  'ADVM',
#  'ADXS',
#  'AE',
#  'AEE',
#  'AEHR',
#  'AEIS',
#  'AEL',
#  'AEMD',
#  'AEO',
#  'AEP',
#  'AERI',
#  'AES',
#  'AEY',
#  'AFG',
#  'AFI',
#  'AFIN',
#  'AFL',
#  'AGCO',
#  'AGE',
#  'AGEN',
#  'AGFS',
#  'AGIO',
#  'AGLE',
#  'AGM',
#  'AGNC',
#  'AGO',
#  'AGR',
#  'AGRX',
#  'AGS',
#  'AGTC',
#  'AGX',
#  'AGYS',
#  'AHH',
#  'AHT',
#  'AIG',
#  'AIMC',
# ...
