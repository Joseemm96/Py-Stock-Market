# %%
# Provides ways to work with large multidimensional arrays
import numpy as np 
# Allows for further data manipulation and analysis
import pandas as pd
from pandas_datareader import data as web # Reads stock data 
import matplotlib.pyplot as plt # Plotting
import matplotlib.dates as mdates # Styling dates
# %matplotlib inline

import datetime as dt # For defining dates
import mplfinance as mpf # Matplotlib finance

import time

# Used to get data from a directory
import os
from os import listdir
from os.path import isfile, join

# %% [markdown]
# # Holds Stocks Not Downloaded

# %%
stocks_not_downloaded = []
missing_stocks = []

# %% [markdown]
# # Save Stock Data to CSV

# %%
def save_to_csv_from_yahoo(folder, ticker , syear, smonth, sday, eyear, emonth, eday):
    start = dt.datetime(syear, smonth, sday)
    end = dt.datetime(eyear, emonth, eday)
    try:
        print("Get Data for :", ticker)
        df = web.DataReader(ticker, 'yahoo', start, end)['Adj Close'] #ADJ close es el cierre por día
        time.sleep(10)
        df.to_csv(folder + ticker + '.csv')
    except Exception as ex:
        stocks_not_downloaded.append(ticker)
        print("Couldn't get Data for: ", ticker)

# %% [markdown]
# # Returns a Stock Dataframe from a CSV

# %%
def get_stock_df_from_csv(folder, ticker):
    try:
        df = pd.read_csv(folder + ticker + '.csv')
    except FileNotFoundError:
        print("File doesn't exist")
    else:
        return df

# %% [markdown]
# # Returns a named columns data from a csv

# %%
def get_column_from_csv(file, col_name):
    try:
        df = pd.read_csv(file)
    except FileNotFoundError:
        print("File doesn't exist")
    else:
        return df[col_name]

# %% [markdown]
# # Test receiving stock tickers

# %%
# Doble backslash porque con uno error :(
path = "C:\\Users\\Jose Enrique\\Documents\\Programming\\Python\\DS-Finance\\Wilshire-5000-Stocks.csv"
tickers = get_column_from_csv(path, "Ticker")
tickers
# Out:
# 0          A
# 1         AA
# 2        AAL
# 3       AAME
# 4        AAN
#         ...
# 3476    ZUMZ
# 3477     ZUO
# 3478    ZYNE
# 3479    ZYXI
# 3480    ZNGA
# Name: Ticker, Length: 3481, dtype: object

# %% [markdown]
# # Get 4 years of data for the 1st 20 stocks

# %%
folder = "C:\\Users\\Jose Enrique\\Documents\\Programming\\Python\\DS-Finance\\Stock List\\"
for x in range(20):
    save_to_csv_from_yahoo(folder, tickers[x], 2018, 1, 1, 2022, 1, 26)
print("finished")
# Out:
# Get Data for : A
# Get Data for : AA
# Get Data for : AAL
# Get Data for : AAME
# Get Data for : AAN
# Get Data for : AAOI
# Get Data for : AAON
# Get Data for : AAP
# Get Data for : AAPL
# Get Data for : AAT
# Get Data for : AAWW
# Get Data for : AAXN
# Couldn't get Data for:  AAXN
# Get Data for : ABBV
# Get Data for : ABC
# Get Data for : ABCB
# Get Data for : ABEO
# Get Data for : ABG
# Get Data for : ABIO
# Get Data for : ABM
# Get Data for : ABMD
# finished

# %% [markdown]
# # Download Stocks in Blocks

# %%
for x in range(2216, 3480):
    save_to_csv_from_yahoo(folder, tickers[x], 2018, 1, 1, 2022, 1, 26)
print("finished")
stocks_not_downloaded
# Out:
# Get Data for : PDCE
# Get Data for : PDCO
# Get Data for : PDEX
# Get Data for : PDFS
# Get Data for : PDLB
# Get Data for : PDLI
# Couldn't get Data for:  PDLI
# Get Data for : PDM
# Get Data for : PE
# Couldn't get Data for:  PE
# Get Data for : PEB
# Get Data for : PEBK
# Get Data for : PEBO
# Get Data for : PED
# Get Data for : PEG
# Get Data for : PEGA
# Get Data for : PEI
# Get Data for : PEIX
# Couldn't get Data for:  PEIX
# Get Data for : PEN
# Get Data for : PENN
# Get Data for : PEP
# Get Data for : PESI
# Get Data for : PETQ
# Get Data for : PETS
# Get Data for : PFBC
# Get Data for : PFBI
# Couldn't get Data for:  PFBI
# Get Data for : PFE
# Get Data for : PFG
# Get Data for : PFGC
# Get Data for : PFIE
# Get Data for : PFIN
# Get Data for : PFIS
# Get Data for : PFMT
# Get Data for : PFNX
# Couldn't get Data for:  PFNX
# Get Data for : PFPT
# Couldn't get Data for:  PFPT
# Get Data for : PFS
# Get Data for : PFSW
# Get Data for : PG
# Get Data for : PGC
# Get Data for : PGNX
# Couldn't get Data for:  PGNX
# Get Data for : PGR
# Get Data for : PGRE
# Get Data for : PGTI
# Get Data for : PH
# Get Data for : PHAS
# Get Data for : PHIO
# Get Data for : PHM
# Get Data for : PHX
# Get Data for : PI
# Get Data for : PICO
# Couldn't get Data for:  PICO
# Get Data for : PIH
# Couldn't get Data for:  PIH
# Get Data for : PII
# Get Data for : PINC
# Get Data for : PINS
# Get Data for : PJT
# Get Data for : PK
# Get Data for : PKBK
# Get Data for : PKE
# Get Data for : PKG
# Get Data for : PKI
# Get Data for : PKOH
# Get Data for : PLAB
# Get Data for : PLAN
# Get Data for : PLAY
# Get Data for : PLBC
# Get Data for : PLCE
# Get Data for : PLD
# Get Data for : PLNT
# Get Data for : PLOW
# Get Data for : PLPC
# Get Data for : PLSE
# Get Data for : PLT
# Couldn't get Data for:  PLT
# Get Data for : PLUG
# Get Data for : PLUS
# Get Data for : PLXP
# Get Data for : PLXS
# Get Data for : PLYA
# Get Data for : PLYM
# Get Data for : PM
# Get Data for : PMBC
# Couldn't get Data for:  PMBC
# Get Data for : PMD
# Get Data for : PMT
# Get Data for : PMTS
# Get Data for : PNBK
# Get Data for : PNC
# Get Data for : PNFP
# Get Data for : PNM
# Get Data for : PNR
# Get Data for : PNRG
# Get Data for : PNW
# Get Data for : PODD
# Get Data for : POL
# Couldn't get Data for:  POL
# Get Data for : POOL
# Get Data for : POR
# Get Data for : POST
# Get Data for : POWI
# Get Data for : POWL
# Get Data for : PPBI
# Get Data for : PPC
# Get Data for : PPG
# Get Data for : PPIH
# Get Data for : PPL
# Get Data for : PPSI
# Get Data for : PQG
# Couldn't get Data for:  PQG
# Get Data for : PRA
# Get Data for : PRAA
# Get Data for : PRAH
# Couldn't get Data for:  PRAH
# Get Data for : PRCP
# Couldn't get Data for:  PRCP
# Get Data for : PRFT
# Get Data for : PRGO
# Get Data for : PRGS
# Get Data for : PRGX
# Couldn't get Data for:  PRGX
# Get Data for : PRI
# Get Data for : PRIM
# Get Data for : PRK
# Get Data for : PRLB
# Get Data for : PRMW
# Get Data for : PRNB
# Couldn't get Data for:  PRNB
# Get Data for : PRO
# Get Data for : PROV
# Get Data for : PRPH
# Get Data for : PRSC
# Couldn't get Data for:  PRSC
# Get Data for : PRSP
# Couldn't get Data for:  PRSP
# Get Data for : PRTA
# Get Data for : PRTK
# Get Data for : PRTS
# Get Data for : PRTY
# Get Data for : PRU
# Get Data for : PRVB
# Get Data for : PS
# Couldn't get Data for:  PS
# Get Data for : PSA
# Get Data for : PSB
# Get Data for : PSMT
# Get Data for : PSN
# Get Data for : PSTG
# Get Data for : PSX
# Get Data for : PTC
# Get Data for : PTCT
# Get Data for : PTE
# Get Data for : PTEN
# Get Data for : PTGX
# Get Data for : PTI
# Couldn't get Data for:  PTI
# Get Data for : PTLA
# Couldn't get Data for:  PTLA
# Get Data for : PTN
# Get Data for : PTSI
# Get Data for : PTVCA
# Couldn't get Data for:  PTVCA
# Get Data for : PTVCB
# Couldn't get Data for:  PTVCB
# Get Data for : PUB
# Couldn't get Data for:  PUB
# Get Data for : PULM
# Get Data for : PUMP
# Get Data for : PVAC
# Couldn't get Data for:  PVAC
# Get Data for : PVBC
# Get Data for : PVH
# Get Data for : PW
# Get Data for : PWOD
# Get Data for : PWR
# Get Data for : PXD
# Get Data for : PXLW
# Get Data for : PYPL
# Get Data for : PZG
# Get Data for : PZN
# Get Data for : PZZA
# Get Data for : QADA
# Couldn't get Data for:  QADA
# Get Data for : QADB
# Couldn't get Data for:  QADB
# Get Data for : QCOM
# Get Data for : QCRH
# Get Data for : QDEL
# Get Data for : QEP
# Couldn't get Data for:  QEP
# Get Data for : QLYS
# Get Data for : QNST
# Get Data for : QRHC
# Get Data for : QRTEA
# Get Data for : QRVO
# Get Data for : QTRX
# Get Data for : QTS
# Couldn't get Data for:  QTS
# Get Data for : QTWO
# Get Data for : QUAD
# Get Data for : QUIK
# Get Data for : QUMU
# Get Data for : QUOT
# Get Data for : R
# Get Data for : RAD
# Get Data for : RAIL
# Get Data for : RAMP
# Get Data for : RARE
# Get Data for : RAVE
# Get Data for : RAVN
# Couldn't get Data for:  RAVN
# Get Data for : RBB
# Get Data for : RBBN
# Get Data for : RBC
# Couldn't get Data for:  RBC
# Get Data for : RBCAA
# Get Data for : RBCN
# Get Data for : RBNC
# Couldn't get Data for:  RBNC
# Get Data for : RC
# Get Data for : RCII
# Get Data for : RCKT
# Get Data for : RCKY
# Get Data for : RCL
# Get Data for : RCM
# Get Data for : RCMT
# Get Data for : RCUS
# Get Data for : RDFN
# Get Data for : RDI
# Get Data for : RDN
# Get Data for : RDNT
# Get Data for : RDUS
# Get Data for : RDVT
# Get Data for : RE
# Get Data for : REED
# Get Data for : REFR
# Get Data for : REG
# Get Data for : REGI
# Get Data for : REGN
# Get Data for : REI
# Get Data for : RELL
# Get Data for : RELV
# Get Data for : REPH
# Get Data for : REPL
# Get Data for : RES
# Get Data for : RESI
# Get Data for : RESN
# Get Data for : RETA
# Get Data for : REV
# Get Data for : REVG
# Get Data for : REX
# Get Data for : REXR
# Get Data for : REZI
# Get Data for : RF
# Get Data for : RFIL
# Get Data for : RFL
# Get Data for : RFP
# Get Data for : RGA
# Get Data for : RGCO
# Get Data for : RGEN
# Get Data for : RGLD
# Get Data for : RGLS
# Get Data for : RGNX
# Get Data for : RGR
# Get Data for : RGS
# Get Data for : RH
# Get Data for : RHE
# Get Data for : RHI
# Get Data for : RHP
# Get Data for : RIBT
# Get Data for : RICK
# Get Data for : RIG
# Get Data for : RIGL
# Get Data for : RILY
# Get Data for : RIOT
# Get Data for : RJF
# Get Data for : RKDA
# Get Data for : RL
# Get Data for : RLGT
# Get Data for : RLGY
# Get Data for : RLH
# Couldn't get Data for:  RLH
# Get Data for : RLI
# Get Data for : RLJ
# Get Data for : RM
# Get Data for : RMAX
# Get Data for : RMBS
# Get Data for : RMCF
# Get Data for : RMD
# Get Data for : RMR
# Get Data for : RMTI
# Get Data for : RNDB
# Get Data for : RNET
# Couldn't get Data for:  RNET
# Get Data for : RNG
# Get Data for : RNR
# Get Data for : RNST
# Get Data for : RNWK
# Get Data for : ROCK
# Get Data for : ROG
# Get Data for : ROIC
# Get Data for : ROK
# Get Data for : ROKU
# Get Data for : ROL
# Get Data for : ROLL
# Get Data for : ROP
# Get Data for : ROST
# Get Data for : RP
# Couldn't get Data for:  RP
# Get Data for : RPAI
# Couldn't get Data for:  RPAI
# Get Data for : RPD
# Get Data for : RPM
# Get Data for : RPT
# Get Data for : RRC
# Get Data for : RRD
# Get Data for : RRGB
# Get Data for : RRR
# Get Data for : RRTS
# Get Data for : RS
# Get Data for : RSG
# Get Data for : RST
# Couldn't get Data for:  RST
# Get Data for : RTIX
# Couldn't get Data for:  RTIX
# Get Data for : RTRX
# Couldn't get Data for:  RTRX
# Get Data for : RTW
# Couldn't get Data for:  RTW
# Get Data for : RUBI
# Couldn't get Data for:  RUBI
# Get Data for : RUBY
# Get Data for : RUN
# Get Data for : RUSHA
# Get Data for : RUSHB
# Get Data for : RUTH
# Get Data for : RVI
# Get Data for : RVLT
# Couldn't get Data for:  RVLT
# Get Data for : RVNC
# Get Data for : RVP
# Get Data for : RVSB
# Get Data for : RWT
# Get Data for : RXN
# Couldn't get Data for:  RXN
# Get Data for : RYAM
# Get Data for : RYI
# Get Data for : RYN
# Get Data for : RYTM
# Get Data for : SABR
# Get Data for : SACH
# Get Data for : SAFE
# Get Data for : SAFM
# Get Data for : SAFT
# Get Data for : SAGE
# Get Data for : SAH
# Get Data for : SAIA
# Get Data for : SAIC
# Get Data for : SAIL
# Get Data for : SAL
# Get Data for : SALM
# Get Data for : SAM
# Get Data for : SAMG
# Get Data for : SANM
# Get Data for : SANW
# Get Data for : SASR
# Get Data for : SATS
# Get Data for : SAVE
# Get Data for : SBAC
# Get Data for : SBBX
# Couldn't get Data for:  SBBX
# Get Data for : SBCF
# Get Data for : SBFG
# Get Data for : SBGI
# Get Data for : SBH
# Get Data for : SBNY
# Get Data for : SBOW
# Get Data for : SBPH
# Couldn't get Data for:  SBPH
# Get Data for : SBRA
# Get Data for : SBSI
# Get Data for : SBT
# Get Data for : SBUX
# Get Data for : SC
# Get Data for : SCHL
# Get Data for : SCHN
# Get Data for : SCHW
# Get Data for : SCI
# Get Data for : SCL
# Get Data for : SCON
# Couldn't get Data for:  SCON
# Get Data for : SCOR
# Get Data for : SCPL
# Get Data for : SCS
# Get Data for : SCSC
# Get Data for : SCVL
# Get Data for : SCWX
# Get Data for : SCX
# Get Data for : SCYX
# Get Data for : SD
# Get Data for : SDPI
# Get Data for : SEAC
# Get Data for : SEAS
# Get Data for : SEB
# Get Data for : SEDG
# Get Data for : SEE
# Get Data for : SEIC
# Get Data for : SELB
# Get Data for : SELF
# Get Data for : SEM
# Get Data for : SENEA
# Get Data for : SENEB
# Get Data for : SENS
# Get Data for : SERV
# Couldn't get Data for:  SERV
# Get Data for : SESN
# Get Data for : SF
# Get Data for : SFBC
# Get Data for : SFBS
# Get Data for : SFE
# Get Data for : SFIX
# Get Data for : SFM
# Get Data for : SFNC
# Get Data for : SFST
# Get Data for : SGA
# Get Data for : SGC
# Get Data for : SGEN
# Get Data for : SGH
# Get Data for : SGMA
# Get Data for : SGMO
# Get Data for : SGMS
# Get Data for : SGRP
# Get Data for : SGRY
# Get Data for : SHAK
# Get Data for : SHBI
# Get Data for : SHEN
# Get Data for : SHLO
# Couldn't get Data for:  SHLO
# Get Data for : SHO
# Get Data for : SHOO
# Get Data for : SHSP
# Couldn't get Data for:  SHSP
# Get Data for : SHW
# Get Data for : SIBN
# Get Data for : SIEB
# Get Data for : SIEN
# Get Data for : SIF
# Get Data for : SIG
# Get Data for : SIGA
# Get Data for : SIGI
# Get Data for : SILK
# Get Data for : SINT
# Get Data for : SIRI
# Get Data for : SITC
# Get Data for : SITE
# Get Data for : SITO
# Couldn't get Data for:  SITO
# Get Data for : SIVB
# Get Data for : SIX
# Get Data for : SJI
# Get Data for : SJM
# Get Data for : SJW
# Get Data for : SKT
# Get Data for : SKX
# Get Data for : SKY
# Get Data for : SKYW
# Get Data for : SLAB
# Get Data for : SLB
# Get Data for : SLCA
# Get Data for : SLCT
# Couldn't get Data for:  SLCT
# Get Data for : SLDB
# Get Data for : SLG
# Get Data for : SLGN
# Get Data for : SLM
# Get Data for : SLNO
# Get Data for : SLP
# Get Data for : SLS
# Get Data for : SM
# Get Data for : SMAR
# Get Data for : SMBC
# Get Data for : SMBK
# Get Data for : SMED
# Get Data for : SMG
# Get Data for : SMIT
# Get Data for : SMMF
# Get Data for : SMP
# Get Data for : SMPL
# Get Data for : SMRT
# Get Data for : SMSI
# Get Data for : SMTC
# Get Data for : SNA
# Get Data for : SNAP
# Get Data for : SNBR
# Get Data for : SNCR
# Get Data for : SND
# Get Data for : SNDR
# Get Data for : SNDX
# Get Data for : SNFCA
# Get Data for : SNOA
# Get Data for : SNPS
# Get Data for : SNR
# Couldn't get Data for:  SNR
# Get Data for : SNSS
# Couldn't get Data for:  SNSS
# Get Data for : SNV
# Get Data for : SNX
# Get Data for : SO
# Get Data for : SOHO
# Get Data for : SOI
# Get Data for : SOLY
# Couldn't get Data for:  SOLY
# Get Data for : SON
# Get Data for : SONA
# Couldn't get Data for:  SONA
# Get Data for : SONO
# Get Data for : SP
# Get Data for : SPB
# Get Data for : SPG
# Get Data for : SPGI
# Get Data for : SPKE
# Couldn't get Data for:  SPKE
# Get Data for : SPLK
# Get Data for : SPN
# Couldn't get Data for:  SPN
# Get Data for : SPNE
# Get Data for : SPOK
# Get Data for : SPPI
# Get Data for : SPR
# Get Data for : SPRO
# Get Data for : SPRT
# Couldn't get Data for:  SPRT
# Get Data for : SPSC
# Get Data for : SPTN
# Get Data for : SPWH
# Get Data for : SPWR
# Get Data for : SPXC
# Get Data for : SQ
# Get Data for : SQBG
# Couldn't get Data for:  SQBG
# Get Data for : SR
# Get Data for : SRC
# Get Data for : SRCE
# Get Data for : SRCL
# Get Data for : SRDX
# Get Data for : SRE
# Get Data for : SREV
# Get Data for : SRG
# Get Data for : SRI
# Get Data for : SRNE
# Get Data for : SRPT
# Get Data for : SRRK
# Get Data for : SRT
# Get Data for : SRTS
# Get Data for : SSB
# Get Data for : SSBI
# Get Data for : SSD
# Get Data for : SSKN
# Get Data for : SSNC
# Get Data for : SSP
# Get Data for : SSTI
# Get Data for : SSTK
# Get Data for : ST
# Get Data for : STAA
# Get Data for : STAG
# Get Data for : STAR
# Get Data for : STAY
# Couldn't get Data for:  STAY
# Get Data for : STBA
# Get Data for : STC
# Get Data for : STCN
# Get Data for : STE
# Get Data for : STFC
# Get Data for : STIM
# Get Data for : STKS
# Get Data for : STL
# Get Data for : STLD
# Get Data for : STMP
# Couldn't get Data for:  STMP
# Get Data for : STND
# Couldn't get Data for:  STND
# Get Data for : STOR
# Get Data for : STRA
# Get Data for : STRL
# Get Data for : STRM
# Get Data for : STRS
# Get Data for : STRT
# Get Data for : STT
# Get Data for : STWD
# Get Data for : STX
# Get Data for : STXB
# Get Data for : STZ
# Get Data for : SUI
# Get Data for : SUM
# Get Data for : SUMR
# Get Data for : SUNW
# Get Data for : SUP
# Get Data for : SUPN
# Get Data for : SVBI
# Couldn't get Data for:  SVBI
# Get Data for : SVMK
# Couldn't get Data for:  SVMK
# Get Data for : SVRA
# Get Data for : SVT
# Get Data for : SWAV
# Get Data for : SWCH
# Get Data for : SWK
# Get Data for : SWKS
# Get Data for : SWM
# Get Data for : SWN
# Get Data for : SWX
# Get Data for : SXC
# Get Data for : SXI
# Get Data for : SXT
# Get Data for : SYBT
# Get Data for : SYBX
# Get Data for : SYF
# Get Data for : SYK
# Get Data for : SYKE
# Couldn't get Data for:  SYKE
# Get Data for : SYN
# Get Data for : SYNA
# Get Data for : SYNC
# Couldn't get Data for:  SYNC
# Get Data for : SYNH
# Get Data for : SYNL
# Get Data for : SYPR
# Get Data for : SYRS
# Get Data for : SYX
# Couldn't get Data for:  SYX
# Get Data for : SYY
# Get Data for : T
# Get Data for : TACO
# Get Data for : TACT
# Get Data for : TAIT
# Get Data for : TALO
# Get Data for : TAP
# Get Data for : TAST
# Get Data for : TAT
# Couldn't get Data for:  TAT
# Get Data for : TAYD
# Get Data for : TBBK
# Get Data for : TBI
# Get Data for : TBIO
# Couldn't get Data for:  TBIO
# Get Data for : TBK
# Get Data for : TBNK
# Get Data for : TBPH
# Get Data for : TCBI
# Get Data for : TCBK
# Get Data for : TCDA
# Get Data for : TCF
# Couldn't get Data for:  TCF
# Get Data for : TCFC
# Get Data for : TCI
# Get Data for : TCMD
# Get Data for : TCO
# Couldn't get Data for:  TCO
# Get Data for : TCON
# Get Data for : TCS
# Get Data for : TDC
# Get Data for : TDG
# Get Data for : TDOC
# Get Data for : TDS
# Get Data for : TDW
# Get Data for : TDY
# Get Data for : TECD
# Couldn't get Data for:  TECD
# Get Data for : TECH
# Get Data for : TEL
# Get Data for : TELL
# Get Data for : TEN
# Get Data for : TENB
# Get Data for : TENX
# Get Data for : TER
# Get Data for : TERP
# Couldn't get Data for:  TERP
# Get Data for : TESS
# Get Data for : TEUM
# Get Data for : TEX
# Get Data for : TFSL
# Get Data for : TFX
# Get Data for : TG
# Get Data for : TGEN
# Get Data for : TGI
# Get Data for : TGLS
# Get Data for : TGNA
# Get Data for : TGT
# Get Data for : TGTX
# Get Data for : THC
# Get Data for : THFF
# Get Data for : THG
# Get Data for : THO
# Get Data for : THR
# Get Data for : THRM
# Get Data for : THS
# Get Data for : TIF
# Couldn't get Data for:  TIF
# Get Data for : TILE
# Get Data for : TIPT
# Get Data for : TISI
# Get Data for : TITN
# Get Data for : TJX
# Get Data for : TKR
# Get Data for : TLF
# Couldn't get Data for:  TLF
# Get Data for : TLGT
# Couldn't get Data for:  TLGT
# Get Data for : TLRD
# Couldn't get Data for:  TLRD
# Get Data for : TLYS
# Get Data for : TMDX
# Get Data for : TMHC
# Get Data for : TMO
# Get Data for : TMP
# Get Data for : TMST
# Get Data for : TMUS
# Get Data for : TNAV
# Couldn't get Data for:  TNAV
# Get Data for : TNC
# Get Data for : TNDM
# Get Data for : TNET
# Get Data for : TNXP
# Get Data for : TOL
# Get Data for : TORC
# Couldn't get Data for:  TORC
# Get Data for : TOWN
# Get Data for : TPB
# Get Data for : TPC
# Get Data for : TPH
# Get Data for : TPHS
# Get Data for : TPIC
# Get Data for : TPR
# Get Data for : TPRE
# Couldn't get Data for:  TPRE
# Get Data for : TPTX
# Get Data for : TPX
# Get Data for : TR
# Get Data for : TRC
# Get Data for : TRCH
# Couldn't get Data for:  TRCH
# Get Data for : TREC
# Get Data for : TREE
# Get Data for : TREX
# Get Data for : TRGP
# Get Data for : TRHC
# Get Data for : TRIP
# Get Data for : TRMB
# Get Data for : TRMK
# Get Data for : TRN
# Get Data for : TRNO
# Get Data for : TRNS
# Get Data for : TROW
# Get Data for : TROX
# Get Data for : TRS
# Get Data for : TRST
# Get Data for : TRT
# Get Data for : TRTN
# Get Data for : TRTX
# Get Data for : TRU
# Get Data for : TRUE
# Couldn't get Data for:  TRUE
# Get Data for : TRUP
# Get Data for : TRV
# Get Data for : TRVN
# Get Data for : TRWH
# Couldn't get Data for:  TRWH
# Get Data for : TRXC
# Couldn't get Data for:  TRXC
# Get Data for : TSBK
# Get Data for : TSC
# Get Data for : TSCO
# Get Data for : TSE
# Get Data for : TSLA
# Get Data for : TSN
# Get Data for : TSQ
# Get Data for : TTC
# Get Data for : TTD
# Get Data for : TTEC
# Get Data for : TTEK
# Get Data for : TTGT
# Get Data for : TTI
# Get Data for : TTMI
# Get Data for : TTNP
# Get Data for : TTOO
# Get Data for : TTPH
# Couldn't get Data for:  TTPH
# Get Data for : TTWO
# Get Data for : TUP
# Get Data for : TUSK
# Get Data for : TVTY
# Get Data for : TW
# Get Data for : TWI
# Get Data for : TWIN
# Get Data for : TWLO
# Get Data for : TWMC
# Couldn't get Data for:  TWMC
# Get Data for : TWNK
# Get Data for : TWO
# Get Data for : TWOU
# Get Data for : TWST
# Get Data for : TWTR
# Get Data for : TXMD
# Get Data for : TXN
# Get Data for : TXRH
# Get Data for : TXT
# Get Data for : TYL
# Get Data for : TYME
# Get Data for : TZOO
# Get Data for : UA
# Get Data for : UAA
# Get Data for : UAL
# Get Data for : UAMY
# Get Data for : UBA
# Get Data for : UBCP
# Get Data for : UBER
# Get Data for : UBFO
# Get Data for : UBOH
# Get Data for : UBSI
# Get Data for : UCBI
# Get Data for : UCTT
# Get Data for : UDR
# Get Data for : UE
# Get Data for : UEC
# Get Data for : UEIC
# Get Data for : UFAB
# Get Data for : UFCS
# Get Data for : UFI
# Get Data for : UFPI
# Get Data for : UFPT
# Get Data for : UFS
# Couldn't get Data for:  UFS
# Get Data for : UG
# Get Data for : UGI
# Get Data for : UHAL
# Get Data for : UHS
# Get Data for : UHT
# Get Data for : UIHC
# Get Data for : UIS
# Get Data for : ULBI
# Get Data for : ULH
# Get Data for : ULTA
# Get Data for : UMBF
# Get Data for : UMH
# Get Data for : UMPQ
# Get Data for : UNAM
# Get Data for : UNB
# Get Data for : UNF
# Get Data for : UNFI
# Get Data for : UNH
# Get Data for : UNIT
# Get Data for : UNM
# Get Data for : UNP
# Get Data for : UNTY
# Get Data for : UNVR
# Get Data for : UONE
# Get Data for : UONEK
# Get Data for : UPLD
# Get Data for : UPS
# Get Data for : UPWK
# Get Data for : URBN
# Get Data for : URI
# Get Data for : UROV
# Couldn't get Data for:  UROV
# Get Data for : USAK
# Get Data for : USAP
# Get Data for : USAT
# Couldn't get Data for:  USAT
# Get Data for : USB
# Get Data for : USCR
# Couldn't get Data for:  USCR
# Get Data for : USEG
# Get Data for : USFD
# Get Data for : USLM
# Get Data for : USM
# Get Data for : USNA
# Get Data for : USPH
# Get Data for : USWS
# Get Data for : USX
# Get Data for : UTHR
# Get Data for : UTI
# Get Data for : UTL
# Get Data for : UTMD
# Get Data for : UUU
# Get Data for : UVE
# Get Data for : UVSP
# Get Data for : UVV
# Get Data for : V
# Get Data for : VAC
# Get Data for : VAL
# Get Data for : VALU
# Get Data for : VAPO
# Get Data for : VAR
# Couldn't get Data for:  VAR
# Get Data for : VBFC
# Get Data for : VBIV
# Get Data for : VBTX
# Get Data for : VC
# Get Data for : VCEL
# Get Data for : VCRA
# Get Data for : VCTR
# Get Data for : VCYT
# Get Data for : VEC
# Get Data for : VECO
# Get Data for : VEEV
# Get Data for : VER
# Couldn't get Data for:  VER
# Get Data for : VERI
# Get Data for : VERU
# Get Data for : VFC
# Get Data for : VG
# Get Data for : VGR
# Get Data for : VHC
# Get Data for : VIAV
# Get Data for : VICI
# Get Data for : VICR
# Get Data for : VIRC
# Get Data for : VIRT
# Get Data for : VIVO
# Get Data for : VKTX
# Get Data for : VLGEA
# Get Data for : VLO
# Get Data for : VLY
# Get Data for : VMC
# Get Data for : VMI
# Get Data for : VMW
# Get Data for : VNCE
# Get Data for : VNDA
# Get Data for : VNE
# Get Data for : VNO
# Get Data for : VNRX
# Get Data for : VNTR
# Get Data for : VOXX
# Get Data for : VOYA
# Get Data for : VPG
# Get Data for : VRA
# Get Data for : VRAY
# Get Data for : VREX
# Get Data for : VRNS
# Get Data for : VRNT
# Get Data for : VRRM
# Get Data for : VRS
# Get Data for : VRSK
# Get Data for : VRSN
# Get Data for : VRTS
# Get Data for : VRTU
# Couldn't get Data for:  VRTU
# Get Data for : VRTV
# Get Data for : VRTX
# Get Data for : VSAT
# Get Data for : VSEC
# Get Data for : VSH
# Get Data for : VSLR
# Couldn't get Data for:  VSLR
# Get Data for : VST
# Get Data for : VSTM
# Get Data for : VSTO
# Get Data for : VTNR
# Get Data for : VTR
# Get Data for : VTVT
# Get Data for : VUZI
# Get Data for : VVI
# Get Data for : VVUS
# Couldn't get Data for:  VVUS
# Get Data for : VVV
# Get Data for : VXRT
# Get Data for : VYGR
# Get Data for : VZ
# Get Data for : W
# Get Data for : WAB
# Get Data for : WABC
# Get Data for : WAFD
# Get Data for : WAL
# Get Data for : WASH
# Get Data for : WAT
# Get Data for : WATT
# Get Data for : WBA
# Get Data for : WBS
# Get Data for : WBT
# Get Data for : WCC
# Get Data for : WD
# Get Data for : WDAY
# Get Data for : WDC
# Get Data for : WDFC
# Get Data for : WDR
# Couldn't get Data for:  WDR
# Get Data for : WEC
# Get Data for : WELL
# Get Data for : WEN
# Get Data for : WERN
# Get Data for : WETF
# Get Data for : WEX
# Get Data for : WEYS
# Get Data for : WFC
# Get Data for : WGO
# Get Data for : WH
# Get Data for : WHD
# Get Data for : WHG
# Get Data for : WHLM
# Get Data for : WHLR
# Get Data for : WHR
# Get Data for : WIFI
# Couldn't get Data for:  WIFI
# Get Data for : WINA
# Get Data for : WING
# Get Data for : WIRE
# Get Data for : WK
# Get Data for : WKHS
# Get Data for : WLDN
# Get Data for : WLFC
# Get Data for : WLK
# Get Data for : WLL
# Get Data for : WLTW
# Couldn't get Data for:  WLTW
# Get Data for : WM
# Get Data for : WMB
# Get Data for : WMC
# Get Data for : WMGI
# Couldn't get Data for:  WMGI
# Get Data for : WMK
# Get Data for : WMS
# Get Data for : WMT
# Get Data for : WNC
# Get Data for : WNEB
# Get Data for : WOR
# Get Data for : WOW
# Get Data for : WPC
# Get Data for : WPG
# Couldn't get Data for:  WPG
# Get Data for : WPX
# Couldn't get Data for:  WPX
# Get Data for : WRB
# Get Data for : WRE
# Get Data for : WRI
# Couldn't get Data for:  WRI
# Get Data for : WRK
# Get Data for : WRLD
# Get Data for : WRTC
# Couldn't get Data for:  WRTC
# Get Data for : WSBC
# Get Data for : WSBF
# Get Data for : WSC
# Get Data for : WSFS
# Get Data for : WSM
# Get Data for : WSO
# Get Data for : WSR
# Get Data for : WST
# Get Data for : WSTG
# Get Data for : WSTL
# Get Data for : WTBA
# Get Data for : WTFC
# Get Data for : WTI
# Get Data for : WTM
# Get Data for : WTRH
# Get Data for : WTS
# Get Data for : WTT
# Get Data for : WTTR
# Get Data for : WU
# Get Data for : WVE
# Get Data for : WVFC
# Get Data for : WVVI
# Get Data for : WWD
# Get Data for : WWE
# Get Data for : WWR
# Get Data for : WWW
# Get Data for : WY
# Get Data for : WYND
# Couldn't get Data for:  WYND
# Get Data for : WYNN
# Get Data for : WYY
# Get Data for : X
# Get Data for : XAN
# Couldn't get Data for:  XAN
# Get Data for : XBIT
# Get Data for : XEC
# Couldn't get Data for:  XEC
# Get Data for : XEL
# Get Data for : XELA
# Get Data for : XELB
# Get Data for : XENT
# Get Data for : XERS
# Get Data for : XHR
# Get Data for : XLNX
# Get Data for : XLRN
# Couldn't get Data for:  XLRN
# Get Data for : XNCR
# Get Data for : XOG
# Couldn't get Data for:  XOG
# Get Data for : XOM
# Get Data for : XOMA
# Get Data for : XONE
# Couldn't get Data for:  XONE
# Get Data for : XPER
# Get Data for : XPL
# Get Data for : XPO
# Get Data for : XRAY
# Get Data for : XRX
# Get Data for : XSPA
# Get Data for : XTNT
# Get Data for : XXII
# Get Data for : XYL
# Get Data for : Y
# Get Data for : YELP
# Get Data for : YETI
# Get Data for : YEXT
# Get Data for : YMAB
# Get Data for : YORW
# Get Data for : YRCW
# Couldn't get Data for:  YRCW
# Get Data for : YTEN
# Get Data for : YUM
# Get Data for : Z
# Get Data for : ZAGG
# Couldn't get Data for:  ZAGG
# Get Data for : ZBH
# Get Data for : ZBRA
# Get Data for : ZDGE
# Get Data for : ZEN
# Get Data for : ZEUS
# Get Data for : ZG
# Get Data for : ZGNX
# Get Data for : ZION
# Get Data for : ZIOP
# Get Data for : ZIXI
# Couldn't get Data for:  ZIXI
# Get Data for : ZM
# Get Data for : ZN
# Couldn't get Data for:  ZN
# Get Data for : ZNGA
# Get Data for : ZS
# Get Data for : ZSAN
# Get Data for : ZTS
# Get Data for : ZUMZ
# Get Data for : ZUO
# Get Data for : ZYNE
# Get Data for : UONEK
# Get Data for : URBN
# Get Data for : UROV
# Couldn't get Data for:  UROV
# Get Data for : UBA
# Get Data for : ECOL
# Get Data for : USEG
# Get Data for : USFD
# Get Data for : USWS
# Get Data for : USX
# Get Data for : USAT
# Couldn't get Data for:  USAT
# Get Data for : USAK
# Get Data for : USNA
# Get Data for : USIO
# Get Data for : UTMD
# Get Data for : EGY
# Get Data for : MTN
# Get Data for : VAL
# Get Data for : VLO
# Get Data for : VLY
# Get Data for : VMI
# Get Data for : VALU
# Get Data for : VVV
# Get Data for : VNDA
# Get Data for : VAPO
# Get Data for : VREX
# Get Data for : VAR
# Couldn't get Data for:  VAR
# Get Data for : VRNS
# Get Data for : VXRT
# Get Data for : VBIV
# Get Data for : VGR
# Get Data for : VEC
# Get Data for : VECO
# Get Data for : VEEV
# Get Data for : VNTR
# Get Data for : VTR
# Get Data for : VNE
# Get Data for : VRA
# Get Data for : VCYT
# Get Data for : VSTM
# Get Data for : VER
# Couldn't get Data for:  VER
# Get Data for : VCEL
# Get Data for : VRNT
# Get Data for : VRSN
# Get Data for : VRSK
# Get Data for : VBTX
# Get Data for : VRTV
# Get Data for : VERI
# Get Data for : VZ
# Get Data for : VRML
# Couldn't get Data for:  VRML
# Get Data for : VRRM
# Get Data for : VRS
# Get Data for : VTNR
# Get Data for : VRTX
# Get Data for : VERU
# Get Data for : VFC
# Get Data for : CBS
# Couldn't get Data for:  CBS
# Get Data for : VVI
# Get Data for : VSAT
# Get Data for : VIAV
# Get Data for : VICL
# Couldn't get Data for:  VICL
# Get Data for : VICI
# Get Data for : VICR
# Get Data for : VCTR
# Get Data for : VRAY
# Get Data for : VKTX
# Get Data for : VBFC
# Get Data for : VLGEA
# Get Data for : VNCE
# Get Data for : VIRC
# Get Data for : VHC
# Get Data for : VIRT
# Get Data for : VRTS
# Get Data for : VRTU
# Couldn't get Data for:  VRTU
# Get Data for : V
# Get Data for : VSH
# Get Data for : VPG
# Get Data for : VISL
# Get Data for : VSTO
# Get Data for : VC
# Get Data for : VST
# Get Data for : VSI
# Couldn't get Data for:  VSI
# Get Data for : VSLR
# Couldn't get Data for:  VSLR
# Get Data for : VVUS
# Couldn't get Data for:  VVUS
# Get Data for : VMW
# Get Data for : VCRA
# Get Data for : VNRX
# Get Data for : VISI
# Couldn't get Data for:  VISI
# Get Data for : VG
# Get Data for : VNO
# Get Data for : VOXX
# Get Data for : VOYA
# Get Data for : VYGR
# Get Data for : VSEC
# Get Data for : VTVT
# Get Data for : VMC
# Get Data for : VUZI
# Get Data for : WTI
# Get Data for : WPC
# Get Data for : WRB
# Get Data for : GRA
# Couldn't get Data for:  GRA
# Get Data for : GWW
# Get Data for : WNC
# Get Data for : WBC
# Couldn't get Data for:  WBC
# Get Data for : WDR
# Couldn't get Data for:  WDR
# Get Data for : WTRH
# Get Data for : WBA
# Get Data for : WD
# Get Data for : WMT
# Get Data for : HCC
# Get Data for : WAFD
# Get Data for : WPG
# Couldn't get Data for:  WPG
# Get Data for : WRE
# Get Data for : WASH
# Get Data for : WM
# Get Data for : WAT
# Get Data for : WSBF
# Get Data for : WSO
# Get Data for : WTS
# Get Data for : WVE
# Get Data for : W
# Get Data for : WSTG
# Get Data for : WDFC
# Get Data for : WBS
# Get Data for : WEC
# Get Data for : WRI
# Couldn't get Data for:  WRI
# Get Data for : WMK
# Get Data for : WBT
# Get Data for : WCG
# Couldn't get Data for:  WCG
# Get Data for : WEBK
# Couldn't get Data for:  WEBK
# Get Data for : WFC
# Get Data for : WELL
# Get Data for : WERN
# Get Data for : WSBC
# Get Data for : WAIR
# Couldn't get Data for:  WAIR
# Get Data for : WCC
# Get Data for : WTBA
# Get Data for : WST
# Get Data for : WABC
# Get Data for : WSTL
# Get Data for : WAL
# Get Data for : WMC
# Get Data for : WDC
# Get Data for : WNEB
# Get Data for : WAB
# Get Data for : WLK
# Get Data for : WRK
# Get Data for : WWR
# Get Data for : WHG
# Get Data for : WEX
# Get Data for : WEYS
# Get Data for : WY
# Get Data for : WHLR
# Get Data for : WHR
# Get Data for : WTM
# Get Data for : WSR
# Get Data for : WLL
# Get Data for : WOW
# Get Data for : WYY
# Get Data for : WHLM
# Get Data for : WVVI
# Get Data for : WLDN
# Get Data for : WLH
# Couldn't get Data for:  WLH
# Get Data for : WSM
# Get Data for : WLFC
# Get Data for : WLTW
# Couldn't get Data for:  WLTW
# Get Data for : WSC
# Get Data for : WING
# Get Data for : WINA
# Get Data for : WGO
# Get Data for : WTFC
# Get Data for : WTT
# Get Data for : WETF
# Get Data for : WWW
# Get Data for : WWD
# Get Data for : WDAY
# Get Data for : WKHS
# Get Data for : WK
# Get Data for : WRLD
# Get Data for : INT
# Get Data for : WWE
# Get Data for : WOR
# Get Data for : WPX
# Couldn't get Data for:  WPX
# Get Data for : WRTC
# Couldn't get Data for:  WRTC
# Get Data for : WMGI
# Couldn't get Data for:  WMGI
# Get Data for : WSFS
# Get Data for : WVFC
# Get Data for : WW
# Get Data for : WYND
# Couldn't get Data for:  WYND
# Get Data for : WH
# Get Data for : WYNN
# Get Data for : XFOR
# Get Data for : XBIT
# Get Data for : XELB
# Get Data for : XEL
# Get Data for : XNCR
# Get Data for : XHR
# Get Data for : XERS
# Get Data for : XRX
# Get Data for : XLNX
# Get Data for : XOMA
# Get Data for : XPER
# Get Data for : XPO
# Get Data for : XSPA
# Get Data for : XTNT
# Get Data for : XYL
# Get Data for : YELP
# Get Data for : YETI
# Get Data for : YEXT
# Get Data for : YTEN
# Get Data for : YMAB
# Get Data for : YORW
# Get Data for : YRCW
# Couldn't get Data for:  YRCW
# Get Data for : YUM
# Get Data for : YUMA
# Couldn't get Data for:  YUMA
# Get Data for : CTIB
# Get Data for : ZFGN
# Couldn't get Data for:  ZFGN
# Get Data for : ZAGG
# Couldn't get Data for:  ZAGG
# Get Data for : ZAYO
# Couldn't get Data for:  ZAYO
# Get Data for : ZBRA
# Get Data for : ZDGE
# Get Data for : ZEN
# Get Data for : Z
# Get Data for : ZG
# Get Data for : ZBH
# Get Data for : ZN
# Couldn't get Data for:  ZN
# Get Data for : ZION
# Get Data for : ZIOP
# Get Data for : ZIXI
# Couldn't get Data for:  ZIXI
# Get Data for : ZTS
# Get Data for : ZGNX
# Get Data for : ZM
# Get Data for : ZSAN
# Get Data for : ZVO
# Get Data for : ZS
# Get Data for : ZUMZ
# Get Data for : ZUO
# Get Data for : ZYNE
# Get Data for : ZYXI
# Get Data for : ZNGA
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     354                 try:
# --> 355                     return self._range.index(new_key)
#     356                 except ValueError as err:
#
# ValueError: 3481 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-4f55cad0d793> in <module>
#       1 for x in range(2216, 3500):
# ----> 2     save_to_csv_from_yahoo(folder, tickers[x], 2018, 1, 1, 2022, 1, 26)
#       3 print("finished")
#       4 stocks_not_downloaded
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     880
#     881         elif key_is_scalar:
# --> 882             return self._get_value(key)
#     883
#     884         if is_hashable(key):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#     987
#     988         # Similar to Index.get_value, but we do not fall back to positional
# --> 989         loc = self.index.get_loc(label)
#     990         return self.index._get_values_for_loc(self, loc, label)
#     991
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     355                     return self._range.index(new_key)
#     356                 except ValueError as err:
# --> 357                     raise KeyError(key) from err
#     358             raise KeyError(key)
#     359         return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 3481

# %%
for x in missing_stocks:
    save_to_csv_from_yahoo(folder, x, 2018, 1, 1, 2022, 1, 26)
print("Finished")
stocks_not_downloaded
# Out:
# Finished
# ['AAXN',
#  'PDLI',
#  'PE',
#  'PEIX',
#  'PFBI',
#  'PFNX',
#  'PFPT',
#  'PGNX',
#  'PICO',
#  'PIH',
#  'PLT',
#  'PMBC',
#  'POL',
#  'PQG',
#  'PRAH',
#  'PRCP',
#  'PRGX',
#  'PRNB',
#  'PRSC',
#  'PRSP',
#  'PS',
#  'PTI',
#  'PTLA',
#  'PTVCA',
#  'PTVCB',
#  'PUB',
#  'PVAC',
#  'QADA',
#  'QADB',
#  'QEP',
#  'QTS',
#  'RAVN',
#  'RBC',
#  'RBNC',
#  'RLH',
#  'RNET',
#  'RP',
#  'RPAI',
#  'RST',
#  'RTIX',
#  'RTRX',
#  'RTW',
#  'RUBI',
#  'RVLT',
#  'RXN',
#  'SBBX',
#  'SBPH',
#  'SCON',
#  'SERV',
#  'SHLO',
#  'SHSP',
#  'SITO',
#  'SLCT',
#  'SNR',
#  'SNSS',
#  'SOLY',
#  'SONA',
#  'SPKE',
#  'SPN',
#  'SPRT',
#  'SQBG',
#  'STAY',
#  'STMP',
#  'STND',
#  'SVBI',
#  'SVMK',
#  'SYKE',
#  'SYNC',
#  'SYX',
#  'TAT',
#  'TBIO',
#  'TCF',
#  'TCO',
#  'TECD',
#  'TERP',
#  'TIF',
#  'TLF',
#  'TLGT',
#  'TLRD',
#  'TNAV',
#  'TORC',
#  'TPRE',
#  'TRCH',
#  'TRUE ',
#  'TRWH',
#  'TRXC',
#  'TTPH',
#  'TWMC',
#  'UFS',
#  'UROV',
#  'USAT',
#  'USCR',
#  'VAR',
#  'VER',
#  'VRTU',
#  'VSLR',
#  'VVUS',
#  'WDR',
#  'WIFI',
#  'WLTW',
#  'WMGI',
#  'WPG',
#  'WPX',
#  'WRI',
#  'WRTC',
#  'WYND',
#  'XAN',
#  'XEC',
#  'XLRN',
#  'XOG',
#  'XONE',
#  'YRCW',
#  'ZAGG',
#  'ZIXI',
#  'ZN',
#  'UROV',
#  'USAT',
#  'VAR',
#  'VER',
#  'VRML',
#  'CBS',
#  'VICL',
#  'VRTU',
#  'VSI',
#  'VSLR',
#  'VVUS',
#  'VISI',
#  'GRA',
#  'WBC',
#  'WDR',
#  'WPG',
#  'WRI',
#  'WCG',
#  'WEBK',
#  'WAIR',
#  'WLH',
#  'WLTW',
#  'WPX',
#  'WRTC',
#  'WMGI',
#  'WYND',
#  'YRCW',
#  'YUMA',
#  'ZFGN',
#  'ZAGG',
#  'ZAYO',
#  'ZN',
#  'ZIXI']
